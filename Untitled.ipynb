# %%
import sys
sys.path.append('./src')

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
from economy import Economy as eco
from dynamics import Dynamics as dyn

# %%
n = 100
m = 10
d = 8
b = 1
q = 0
netstring = 'regular'
directed = True
j0 = np.ones(n)
a0 = 0.5 * np.ones(n)

# %%
e = eco(n, m, d, netstring, directed, j0, a0, q, b)

# %%
l_0 = np.sqrt(n)
theta = np.ones(n)
gamma = 1
phi = 1

# %%
e.init_house(l_0, theta, gamma, phi, omega_p=None, f=None, r=None)

# %%
z = 30*np.random.uniform(1,100,n)
sigma = np.random.uniform(0.1,1,n)
alpha = 0.45*(1+np.random.uniform(-0.1,0.1,n))
beta = alpha
alpha_p = alpha
beta_p = alpha
omega = 0.1

# %%
e.init_firms(z, sigma, alpha, alpha_p, beta, beta_p, omega)

# %%
e.set_quantities()

# %%
e.set_eps_cal(1)

# %%
sim = dyn(e, 100000)

# %%
p0 = e.p_eq*(1+np.random.uniform(-0.01,0.01,n))#np.random.uniform(1,10,n)
w0 = 1
g0 = e.g_eq#*(1+np.random.uniform(-0.01,0.01,n)#np.random.uniform(1,10,n)
t1 = e.g_eq*(1+np.random.uniform(-0.01,0.01,n))
s0 = np.zeros((n,n))
B0 = 0

# %%
sim.set_initial_conditions(p0, w0, g0, t1, s0, B0)

# %%
phi = 0.1/n
temp = 0.1

# %%
sim.discrete_dynamics(phi, temp)

# %%
# %matplotlib notebook
f, axs = plt.subplots(figsize=(8,6), nrows=2)
axs[0].plot(sim.prices[1:-1, :])
axs[1].plot(sim.prods[1:-1, :])
#plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1759.9999618530283">

# %%
gai, los, sup, dem = sim.compute_gains_losses_supplies_demand(e, sim.q_demand, sim.q_exchange, sim.prices, sim.prods, sim.stocks, sim.labour)

# %%
# %matplotlib notebook
plt.plot(((gai-los)/(gai+los))[1:,:], linestyle='dashed')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="136.36363340803422">

# %%
# %matplotlib notebook
pib = np.sum(sim.q_exchange[1:-1, 1:, 0], axis=1)
ret = np.log(pib/np.roll(pib,-1))
plt.plot(ret[:-1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# %matplotlib notebook
G = nx.convert_matrix.from_numpy_matrix(e.j)
nx.draw_spring(G, with_labels=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# %matplotlib notebook
plt.imshow(e.j)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
np.where((e.j==e.j.T) & (e.j==1))
# Out:
# (array([ 0,  1,  7, 10, 13, 15]), array([15, 10, 13,  1,  7,  0]))
